# %% [markdown]
# # Question 2: International Coding Competition
#
# Name this Jupyter Notebook as: <br>
# `TASK2_<your name>_<class>_<index number>.ipynb`
#
# For each of the sub-tasks, add a comment statement at the beginning of the code using the hash symbol '#' to indicate the sub-task the program code belongs to.

# %% [markdown]
# ## Task 2.1
# Write an insertion sort function that takes three parameters: `data_list`,`index`,`ascending` and returns a sorted `data_list`.
#
# * `data_list` is a list of tuples.
# * `index` is an integer to specify an index within a tuple.
# * `ascending` is a Boolean flag.
#
# The function will sort `data_list` base on the values at the specified `index` within the tuples. The `ascending` parameter determins the order of the sort: `True` for ascending order, `False` for descending order.
#
# The function specification is:
#
# ```python
# FUNCTION insertion_sort(data_list: List[Tuple], index: Integer, ascending:Boolean) RETURN List[Tuple]
# ```
# | Note: The syntax that follows the positional argument is just type hinting.
#
# <div style="text-align: right">[6]</div>
#
# > Example of `insertion_sort` function call:
# >```python
# > data_list = [(1,'Alice', 85), (2, 'Bob',90), (3,'Charlie',80)]
# > sorted_list = insertion_sort(data_list, 2, ascending=False)
# > print(sorted_list)
# >
# > # Output: [(2,'Bob',90), (1,'Alice',85), (3,'Charlie',80)]
# >```

# %%
# Task 2.1      
def insertion_sort(data_list: list[tuple], index: int, ascending:bool=True) -> list[tuple]:
    sorted_list = []
    for data in data_list:
        i = 0
        try: 
            while bool(data[index] < sorted_list[i][index]) != bool(ascending):
                i += 1
        except IndexError: pass
        sorted_list.insert(i, data)
    return sorted_list

data_list = [(1,'Alice', 85), (2, 'Bob',90), (3,'Charlie',80)]
sorted_list = insertion_sort(data_list, 2, ascending=False)
print(sorted_list)
# Out:
# [(2, 'Bob', 90), (1, 'Alice', 85), (3, 'Charlie', 80)]

# %% [markdown]
# ## Task 2.2
# At an international coding competition, the results of the participants were recorded in a text file `CODING_COMPETITION.txt`.
#
# Each record int he file has the following format, with each field separated by a comma:
# `<participant_id>,<participant_name>,<country>,<score>`
#
# Write a function `task2_2` that takes a `filename` as parameter, reads the comma-separated data from the file and returns the data as a list of tuples:
#
# > Example: After calling function `task2_2`, these sample records in the file: <br>
# >
# > `101,Jong Tan,Singapore,210` <br>
# > `102,Mei Ling,Singapore,190` <br>
# >
# > will be returned as <br>
# > `[('101','Jong Tan','Singapore',210),('102','Mei Ling','Singapore',190)]`
#
# Test your function by calling `task2_2("CODING_COMPETITION.txt")`
# <div style="text-align: right">[5]<div>

# %%
# Task 2.2
import csv

def task2_2(filename: str):
    with open('./Resources/TASK2/'+filename) as f:
        return list(map(tuple, list(csv.reader(f))))

task2_2("CODING_COMPETITION.txt")
# Out:
# [('101', 'Jong Tan', 'Singapore', '210'),
#  ('102', 'Mei Ling', 'Singapore', '190'),
#  ('103', 'John Smith', 'USA', '230'),
#  ('104', 'Emily Davis', 'USA', '85'),
#  ('105', 'Chen Wei', 'China', '220'),
#  ('106', 'Li Na', 'China', '105'),
#  ('107', 'Kumar Patel', 'India', '100'),
#  ('108', 'Arjun Rao', 'India', '95'),
#  ('109', 'Alice Johnson', 'UK', '240'),
#  ('110', 'Robert Brown', 'UK', '70'),
#  ('111', 'Marco Rossi', 'Italy', '225'),
#  ('112', 'Giulia Ferrari', 'Italy', '60'),
#  ('113', 'Ahmed Khan', 'Pakistan', '210'),
#  ('114', 'Ali Ahmed', 'Pakistan', '80'),
#  ('115', 'Olga Ivanova', 'Russia', '220'),
#  ('116', 'Dmitry Petrov', 'Russia', '90'),
#  ('117', 'Paul Walker', 'Australia', '215'),
#  ('118', 'Emily Brown', 'Australia', '85'),
#  ('119', 'Julia Schmidt', 'Germany', '235'),
#  ('120', 'Matthias Mueller', 'Germany', '55'),
#  ('121', 'Yuki Tanaka', 'Japan', '225'),
#  ('122', 'Haruka Sato', 'Japan', '95'),
#  ('123', 'Karen Wilson', 'Canada', '250'),
#  ('124', 'David Wilson', 'Canada', '70'),
#  ('125', 'Lucia Martinez', 'Spain', '205'),
#  ('126', 'Javier Rodriguez', 'Spain', '40'),
#  ('127', 'Michael Lee', 'USA', '220'),
#  ('128', 'Jessica Green', 'USA', '80'),
#  ('129', 'Han Zhang', 'China', '210'),
#  ('130', 'Liang Chen', 'China', '90'),
#  ('131', 'Sarah Johnson', 'UK', '225'),
#  ('132', 'James Wilson', 'UK', '85'),
#  ('133', 'Giovanni Bianchi', 'Italy', '220'),
#  ('134', 'Francesca Russo', 'Italy', '75'),
#  ('135', 'Ali Hassan', 'Pakistan', '205'),
#  ('136', 'Farhan Khan', 'Pakistan', '60'),
#  ('137', 'Anastasia Petrova', 'Russia', '215'),
#  ('138', 'Ivan Kuznetsov', 'Russia', '45'),
#  ('139', 'Daniel Miller', 'Australia', '225'),
#  ('140', 'Laura Smith', 'Australia', '85'),
#  ('141', 'Isabella Rossi', 'Italy', '250'),
#  ('142', 'Leonardo Silva', 'Italy', '40'),
#  ('143', 'Akira Yoshida', 'Japan', '235'),
#  ('144', 'Emi Tanaka', 'Japan', '95'),
#  ('145', 'Emma Thompson', 'Canada', '225'),
#  ('146', 'Matthew Johnson', 'Canada', '70'),
#  ('147', 'Maria Garcia', 'Spain', '220'),
#  ('148', 'Antonio Lopez', 'Spain', '60'),
#  ('149', 'Anna Peterson', 'USA', '250'),
#  ('150', 'Eric Davis', 'USA', '85'),
#  ('151', 'Wei Li', 'China', '225'),
#  ('152', 'Mei Chen', 'China', '55'),
#  ('153', 'Oliver Harris', 'UK', '240'),
#  ('154', 'Sophie White', 'UK', '75'),
#  ('155', 'Francesco Esposito', 'Italy', '210'),
#  ('156', 'Giovanna Conte', 'Italy', '45'),
#  ('157', 'Abdul Rahman', 'Pakistan', '200'),
#  ('158', 'Sana Malik', 'Pakistan', '55'),
#  ('159', 'Sergei Ivanov', 'Russia', '210'),
#  ('160', 'Yulia Ivanova', 'Russia', '80'),
#  ('161', 'Anna Wilson', 'Australia', '225'),
#  ('162', 'Chris Brown', 'Australia', '90'),
#  ('163', 'Karen Taylor', 'Canada', '215'),
#  ('164', 'Michael Lee', 'Canada', '50'),
#  ('165', 'Diego Ramirez', 'Spain', '210'),
#  ('166', 'Laura Martinez', 'Spain', '65'),
#  ('167', 'Nina Li', 'China', '235'),
#  ('168', 'Yan Li', 'China', '185'),
#  ('169', 'Emma Scott', 'UK', '225'),
#  ('170', 'Oliver Jones', 'UK', '80'),
#  ('171', 'Luca Bianchi', 'Italy', '200'),
#  ('172', 'Arianna Giordano', 'Italy', '95'),
#  ('173', 'Asif Ali', 'Pakistan', '195'),
#  ('174', 'Syed Ahmed', 'Pakistan', '50'),
#  ('175', 'Irina Sokolova', 'Russia', '220'),
#  ('176', 'Dmitry Ivanov', 'Russia', '40'),
#  ('177', 'William Harris', 'Australia', '235'),
#  ('178', 'Isabella Brown', 'Australia', '90'),
#  ('179', 'Charlotte Davis', 'Canada', '250'),
#  ('180', 'Joshua Clark', 'Canada', '65'),
#  ('181', 'Antonio Garcia', 'Spain', '225'),
#  ('182', 'Patricia Hernandez', 'Spain', '160'),
#  ('183', 'Lucas Johnson', 'USA', '250'),
#  ('184', 'Amelia Adams', 'USA', '170'),
#  ('185', 'Li Mei', 'China', '220'),
#  ('186', 'Wang Wei', 'China', '85'),
#  ('187', 'Sophie Harris', 'UK', '240'),
#  ('188', 'Jack Wilson', 'UK', '50'),
#  ('189', 'Paolo Conti', 'Italy', '225'),
#  ('190', 'Alice Russo', 'Italy', '60'),
#  ('191', 'Ali Khan', 'Pakistan', '210'),
#  ('192', 'Mehmet Yilmaz', 'Pakistan', '55'),
#  ('193', 'Elena Popova', 'Russia', '225'),
#  ('194', 'Alexei Ivanov', 'Russia', '70'),
#  ('195', 'James Brown', 'Australia', '235'),
#  ('196', 'Olivia Taylor', 'Australia', '190'),
#  ('197', 'Emily White', 'Canada', '230'),
#  ('198', 'John Lee', 'Canada', '55'),
#  ('199', 'Marta Lopez', 'Spain', '220'),
#  ('200', 'Juan Gonzalez', 'Spain', '65'),
#  ('201', 'Arthur King', 'USA', '250'),
#  ('202', 'Evelyn Davis', 'USA', '85'),
#  ('203', 'Zhao Wei', 'China', '225'),
#  ('204', 'Liang Li', 'China', '55'),
#  ('205', 'Hannah Evans', 'UK', '235'),
#  ('206', 'Liam Martin', 'UK', '65'),
#  ('207', 'Valentina Rossi', 'Italy', '220'),
#  ('208', 'Marco Ferri', 'Italy', '70'),
#  ('209', 'Muhammad Ali', 'Pakistan', '200'),
#  ('210', 'Shazia Ahmed', 'Pakistan', '140'),
#  ('211', 'Irina Mikhailova', 'Russia', '215'),
#  ('212', 'Aleksei Morozov', 'Russia', '55'),
#  ('213', 'Ethan Green', 'Australia', '225'),
#  ('214', 'Mia Roberts', 'Australia', '175'),
#  ('215', 'Laura Brown', 'Canada', '250'),
#  ('216', 'Daniel Harris', 'Canada', '170'),
#  ('217', 'Antonio Rodriguez', 'Spain', '220'),
#  ('218', 'Paula Martinez', 'Spain', '45'),
#  ('219', 'Lucas Anderson', 'USA', '235'),
#  ('220', 'Sofia Adams', 'USA', '215'),
#  ('221', 'Chen Li', 'China', '235'),
#  ('222', 'Mei Wang', 'China', '185'),
#  ('223', 'Natalie Green', 'UK', '250'),
#  ('224', 'Oliver Smith', 'UK', '175'),
#  ('225', 'Giuseppe Esposito', 'Italy', '220'),
#  ('226', 'Sofia Mancini', 'Italy', '50'),
#  ('227', 'Ahmed Khan', 'Pakistan', '200'),
#  ('228', 'Asim Raza', 'Pakistan', '35'),
#  ('229', 'Elena Popov', 'Russia', '215'),
#  ('230', 'Sergey Kozlov', 'Russia', '60'),
#  ('231', 'Charlotte Harris', 'Australia', '220'),
#  ('232', 'Jack Wilson', 'Australia', '90'),
#  ('233', 'Rebecca Clark', 'Canada', '235'),
#  ('234', 'Lucas Allen', 'Canada', '50'),
#  ('235', 'Daniel Lopez', 'Spain', '225'),
#  ('236', 'Elena Martinez', 'Spain', '45'),
#  ('237', 'Mason Miller', 'USA', '250'),
#  ('238', 'Olivia White', 'USA', '70'),
#  ('239', 'Yang Liu', 'China', '225'),
#  ('240', 'Yi Wang', 'China', '85'),
#  ('241', 'Jessica Lewis', 'UK', '240'),
#  ('242', 'William Johnson', 'UK', '55'),
#  ('243', 'Giulia Rossi', 'Italy', '230'),
#  ('244', 'Marco Russo', 'Italy', '60'),
#  ('245', 'Saad Khan', 'Pakistan', '200'),
#  ('246', 'Noor Malik', 'Pakistan', '30'),
#  ('247', 'Irina Sokolov', 'Russia', '220'),
#  ('248', 'Alexei Petrov', 'Russia', '40'),
#  ('249', 'James Scott', 'Australia', '235'),
#  ('250', 'Emily Johnson', 'Australia', '90'),
#  ('251', 'Isabella Wilson', 'Canada', '230'),
#  ('252', 'Michael Brown', 'Canada', '65'),
#  ('253', 'Javier Martinez', 'Spain', '225'),
#  ('254', 'Lucia Gonzalez', 'Spain', '50'),
#  ('255', 'Samuel Green', 'USA', '250'),
#  ('256', 'Emily Adams', 'USA', '220'),
#  ('257', 'Lin Zhao', 'China', '235'),
#  ('258', 'Hua Zhang', 'China', '90'),
#  ('259', 'Alice Roberts', 'UK', '240'),
#  ('260', 'James Smith', 'UK', '190'),
#  ('261', 'Giuseppe Russo', 'Italy', '225'),
#  ('262', 'Francesca Bianchi', 'Italy', '60'),
#  ('263', 'Amir Khan', 'Pakistan', '200'),
#  ('264', 'Shahbaz Ahmed', 'Pakistan', '35'),
#  ('265', 'Irina Ivanova', 'Russia', '220'),
#  ('266', 'Dmitry Mikhailov', 'Russia', '30'),
#  ('267', 'Liam Taylor', 'Australia', '230')]

# %% [markdown]
# ## Task 2.3
# Write a function `task2_3` that performs the following:
# * Use the list of tuples returned from the function `task2_2`.
# * Sort the list by country in alphabetical order, using the `insertion_sort` function
# * Within each country, sort the participants by their scores in descending order using the `insertion_sort` function.
# * Write the sorted data to a text file `SCORE_BY_COUNTRY.txt` in the format: <br>
# `<country>,<participant id>,<participant name>,<score>`.
# * Each record should be on a new line
#
# The output file should contain lines of record that is first sorted by country then by score. Sample lines in output file:
#
# <center>
#
# <table border="1">
#   <tr style="font-family: 'Courier New', monospace;">
#     <td>Australia,249,James Scott, 235<br>
#         Australia,267,Liam Taylor, 230<br>
#         Australia,139,Daniel Miller, 225<br>
#         ...<br>
#         Singapore,101,Jong Tan,210<br>
#         ...</td>
#   </tr>
# </table>
#
# </center>
#
# Run your function `task2_3`
# <div style="text-align:right;">[9]</div>

# %%
# Task 2.3

def task2_3():
    data = task2_2("CODING_COMPETITION.txt")
    country_sorted = insertion_sort(data, 2)
    country_set = []
    for row in country_sorted:
        if row[2] in country_set: continue
        country_set.append(row[2])
    country_sorted = map(lambda a: (int(a[0]), a[1], a[2], int(a[3])), country_sorted)
    final_sorted = []
    for country in country_set:
        final_sorted.extend(insertion_sort([row for row in data if row[2] == country], 3, ascending=False))
    for i, row in enumerate(final_sorted):
        try:
            final_sorted[i] = row[2], row[0], row[1], row[3]
        except:
            print(row)
    return list(final_sorted)

task2_3()
# Out:
# [('Australia', '250', 'Emily Johnson', '90'),
#  ('Australia', '232', 'Jack Wilson', '90'),
#  ('Australia', '178', 'Isabella Brown', '90'),
#  ('Australia', '162', 'Chris Brown', '90'),
#  ('Australia', '140', 'Laura Smith', '85'),
#  ('Australia', '118', 'Emily Brown', '85'),
#  ('Australia', '249', 'James Scott', '235'),
#  ('Australia', '195', 'James Brown', '235'),
#  ('Australia', '177', 'William Harris', '235'),
#  ('Australia', '267', 'Liam Taylor', '230'),
#  ('Australia', '213', 'Ethan Green', '225'),
#  ('Australia', '161', 'Anna Wilson', '225'),
#  ('Australia', '139', 'Daniel Miller', '225'),
#  ('Australia', '231', 'Charlotte Harris', '220'),
#  ('Australia', '117', 'Paul Walker', '215'),
#  ('Australia', '196', 'Olivia Taylor', '190'),
#  ('Australia', '214', 'Mia Roberts', '175'),
#  ('Canada', '146', 'Matthew Johnson', '70'),
#  ('Canada', '124', 'David Wilson', '70'),
#  ('Canada', '252', 'Michael Brown', '65'),
#  ('Canada', '180', 'Joshua Clark', '65'),
#  ('Canada', '198', 'John Lee', '55'),
#  ('Canada', '234', 'Lucas Allen', '50'),
#  ('Canada', '164', 'Michael Lee', '50'),
#  ('Canada', '215', 'Laura Brown', '250'),
#  ('Canada', '179', 'Charlotte Davis', '250'),
#  ('Canada', '123', 'Karen Wilson', '250'),
#  ('Canada', '233', 'Rebecca Clark', '235'),
#  ('Canada', '251', 'Isabella Wilson', '230'),
#  ('Canada', '197', 'Emily White', '230'),
#  ('Canada', '145', 'Emma Thompson', '225'),
#  ('Canada', '163', 'Karen Taylor', '215'),
#  ('Canada', '216', 'Daniel Harris', '170'),
#  ('China', '258', 'Hua Zhang', '90'),
#  ('China', '130', 'Liang Chen', '90'),
#  ('China', '240', 'Yi Wang', '85'),
#  ('China', '186', 'Wang Wei', '85'),
#  ('China', '204', 'Liang Li', '55'),
#  ('China', '152', 'Mei Chen', '55'),
#  ('China', '257', 'Lin Zhao', '235'),
#  ('China', '221', 'Chen Li', '235'),
#  ('China', '167', 'Nina Li', '235'),
#  ('China', '239', 'Yang Liu', '225'),
#  ('China', '203', 'Zhao Wei', '225'),
#  ('China', '151', 'Wei Li', '225'),
#  ('China', '185', 'Li Mei', '220'),
#  ('China', '105', 'Chen Wei', '220'),
#  ('China', '129', 'Han Zhang', '210'),
#  ('China', '222', 'Mei Wang', '185'),
#  ('China', '168', 'Yan Li', '185'),
#  ('China', '106', 'Li Na', '105'),
#  ('Germany', '120', 'Matthias Mueller', '55'),
#  ('Germany', '119', 'Julia Schmidt', '235'),
#  ('India', '108', 'Arjun Rao', '95'),
#  ('India', '107', 'Kumar Patel', '100'),
#  ('Italy', '172', 'Arianna Giordano', '95'),
#  ('Italy', '134', 'Francesca Russo', '75'),
#  ('Italy', '208', 'Marco Ferri', '70'),
#  ('Italy', '262', 'Francesca Bianchi', '60'),
#  ('Italy', '244', 'Marco Russo', '60'),
#  ('Italy', '190', 'Alice Russo', '60'),
#  ('Italy', '112', 'Giulia Ferrari', '60'),
#  ('Italy', '226', 'Sofia Mancini', '50'),
#  ('Italy', '156', 'Giovanna Conte', '45'),
#  ('Italy', '142', 'Leonardo Silva', '40'),
#  ('Italy', '141', 'Isabella Rossi', '250'),
#  ('Italy', '243', 'Giulia Rossi', '230'),
#  ('Italy', '261', 'Giuseppe Russo', '225'),
#  ('Italy', '189', 'Paolo Conti', '225'),
#  ('Italy', '111', 'Marco Rossi', '225'),
#  ('Italy', '225', 'Giuseppe Esposito', '220'),
#  ('Italy', '207', 'Valentina Rossi', '220'),
#  ('Italy', '133', 'Giovanni Bianchi', '220'),
#  ('Italy', '155', 'Francesco Esposito', '210'),
#  ('Italy', '171', 'Luca Bianchi', '200'),
#  ('Japan', '144', 'Emi Tanaka', '95'),
#  ('Japan', '122', 'Haruka Sato', '95'),
#  ('Japan', '143', 'Akira Yoshida', '235'),
#  ('Japan', '121', 'Yuki Tanaka', '225'),
#  ('Pakistan', '114', 'Ali Ahmed', '80'),
#  ('Pakistan', '136', 'Farhan Khan', '60'),
#  ('Pakistan', '192', 'Mehmet Yilmaz', '55'),
#  ('Pakistan', '158', 'Sana Malik', '55'),
#  ('Pakistan', '174', 'Syed Ahmed', '50'),
#  ('Pakistan', '264', 'Shahbaz Ahmed', '35'),
#  ('Pakistan', '228', 'Asim Raza', '35'),
#  ('Pakistan', '246', 'Noor Malik', '30'),
#  ('Pakistan', '191', 'Ali Khan', '210'),
#  ('Pakistan', '113', 'Ahmed Khan', '210'),
#  ('Pakistan', '135', 'Ali Hassan', '205'),
#  ('Pakistan', '263', 'Amir Khan', '200'),
#  ('Pakistan', '245', 'Saad Khan', '200'),
#  ('Pakistan', '227', 'Ahmed Khan', '200'),
#  ('Pakistan', '209', 'Muhammad Ali', '200'),
#  ('Pakistan', '157', 'Abdul Rahman', '200'),
#  ('Pakistan', '173', 'Asif Ali', '195'),
#  ('Pakistan', '210', 'Shazia Ahmed', '140'),
#  ('Russia', '116', 'Dmitry Petrov', '90'),
#  ('Russia', '160', 'Yulia Ivanova', '80'),
#  ('Russia', '194', 'Alexei Ivanov', '70'),
#  ('Russia', '230', 'Sergey Kozlov', '60'),
#  ('Russia', '212', 'Aleksei Morozov', '55'),
#  ('Russia', '138', 'Ivan Kuznetsov', '45'),
#  ('Russia', '248', 'Alexei Petrov', '40'),
#  ('Russia', '176', 'Dmitry Ivanov', '40'),
#  ('Russia', '266', 'Dmitry Mikhailov', '30'),
#  ('Russia', '193', 'Elena Popova', '225'),
#  ('Russia', '265', 'Irina Ivanova', '220'),
#  ('Russia', '247', 'Irina Sokolov', '220'),
#  ('Russia', '175', 'Irina Sokolova', '220'),
#  ('Russia', '115', 'Olga Ivanova', '220'),
#  ('Russia', '229', 'Elena Popov', '215'),
#  ('Russia', '211', 'Irina Mikhailova', '215'),
#  ('Russia', '137', 'Anastasia Petrova', '215'),
#  ('Russia', '159', 'Sergei Ivanov', '210'),
#  ('Singapore', '101', 'Jong Tan', '210'),
#  ('Singapore', '102', 'Mei Ling', '190'),
#  ('Spain', '200', 'Juan Gonzalez', '65'),
#  ('Spain', '166', 'Laura Martinez', '65'),
#  ('Spain', '148', 'Antonio Lopez', '60'),
#  ('Spain', '254', 'Lucia Gonzalez', '50'),
#  ('Spain', '236', 'Elena Martinez', '45'),
#  ('Spain', '218', 'Paula Martinez', '45'),
#  ('Spain', '126', 'Javier Rodriguez', '40'),
#  ('Spain', '253', 'Javier Martinez', '225'),
#  ('Spain', '235', 'Daniel Lopez', '225'),
#  ('Spain', '181', 'Antonio Garcia', '225'),
#  ('Spain', '217', 'Antonio Rodriguez', '220'),
#  ('Spain', '199', 'Marta Lopez', '220'),
#  ('Spain', '147', 'Maria Garcia', '220'),
#  ('Spain', '165', 'Diego Ramirez', '210'),
#  ('Spain', '125', 'Lucia Martinez', '205'),
#  ('Spain', '182', 'Patricia Hernandez', '160'),
#  ('UK', '132', 'James Wilson', '85'),
#  ('UK', '170', 'Oliver Jones', '80'),
#  ('UK', '154', 'Sophie White', '75'),
#  ('UK', '110', 'Robert Brown', '70'),
#  ('UK', '206', 'Liam Martin', '65'),
#  ('UK', '242', 'William Johnson', '55'),
#  ('UK', '188', 'Jack Wilson', '50'),
#  ('UK', '223', 'Natalie Green', '250'),
#  ('UK', '259', 'Alice Roberts', '240'),
#  ('UK', '241', 'Jessica Lewis', '240'),
#  ('UK', '187', 'Sophie Harris', '240'),
#  ('UK', '153', 'Oliver Harris', '240'),
#  ('UK', '109', 'Alice Johnson', '240'),
#  ('UK', '205', 'Hannah Evans', '235'),
#  ('UK', '169', 'Emma Scott', '225'),
#  ('UK', '131', 'Sarah Johnson', '225'),
#  ('UK', '260', 'James Smith', '190'),
#  ('UK', '224', 'Oliver Smith', '175'),
#  ('USA', '202', 'Evelyn Davis', '85'),
#  ('USA', '150', 'Eric Davis', '85'),
#  ('USA', '104', 'Emily Davis', '85'),
#  ('USA', '128', 'Jessica Green', '80'),
#  ('USA', '238', 'Olivia White', '70'),
#  ('USA', '255', 'Samuel Green', '250'),
#  ('USA', '237', 'Mason Miller', '250'),
#  ('USA', '201', 'Arthur King', '250'),
#  ('USA', '183', 'Lucas Johnson', '250'),
#  ('USA', '149', 'Anna Peterson', '250'),
#  ('USA', '219', 'Lucas Anderson', '235'),
#  ('USA', '103', 'John Smith', '230'),
#  ('USA', '256', 'Emily Adams', '220'),
#  ('USA', '127', 'Michael Lee', '220'),
#  ('USA', '220', 'Sofia Adams', '215'),
#  ('USA', '184', 'Amelia Adams', '170')]
